# %%
import pandas as pd
import numpy as np

# %%
cwur = pd.read_csv('cwurData.csv')
shanghai = pd.read_csv('shanghaiData.csv')
times_ed = pd.read_csv('timesData.csv')
supp = pd.read_csv('educational_attainment_supplementary_data.csv')
school_country = pd.read_csv('school_and_country_table.csv')
expense = pd.read_csv('education_expenditure_supplementary_data.csv', sep=',', engine='python')

# %%
expense['country'].unique()
# Out:
# array(['OECD Average', 'Australia', 'Austria', 'Belgium', 'Canada',
#        'Chile', 'Czech Republic', 'Denmark', 'Estonia', 'Finland',
#        'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland',
#        'Israel', 'Italy', 'Japan', 'Korea, Republic of', 'Luxembourg',
#        'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Poland',
#        'Portugal', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'United States',
#        '  Brazil', '  Russian Federation'], dtype=object)

# %%
expense['country'].replace(['Korea, Republic of'], 'Republic of Korea', inplace = True)
expense['country'].replace(['  Brazil'], 'Brazil', inplace = True)

times_ed['university_name'].unique()
times_ed['check'] = [*range(0,len(times_ed))]
times_ed.head()
times_ed.iloc[[1, 2, 3, 4]]
# Out:
#   world_rank                        university_name                   country  \
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
# ...

# %% [markdown]
# ## Question 1

# %%
df_min = times_ed.loc[times_ed.groupby('university_name').idxmin('year').reset_index()['check']]
df_max = times_ed.loc[times_ed.groupby('university_name').idxmax('year').reset_index()['check']]

# %%
df_min.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 501     301-350                        Aalborg University         Denmark
# 502     301-350                          Aalto University         Finland
# 166         167                         Aarhus University         Denmark
# 476     276-300                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations income total_score  \
# 2405      14.2          17.9       3.7       35.7      -           -
# 501       19.0          75.3      20.0       27.1   36.4           -
# 502       26.2          49.0      22.2       37.5   61.9           -
# 166       38.1          33.4      55.6       57.3   61.5        49.9
# 476       19.8          63.8      15.5       56.6   35.5           -
#
#      num_students  student_staff_ratio international_students  \
# ...

# %%
df_max.head()
# Out:
#      world_rank                           university_name         country  \
# 2405    601-800  AGH University of Science and Technology          Poland
# 2003    201-250                        Aalborg University         Denmark
# 2056    251-300                          Aalto University         Finland
# 1908       =106                         Aarhus University         Denmark
# 2105    301-350                    Aberystwyth University  United Kingdom
#
#       teaching international  research  citations income total_score  \
# 2405      14.2          17.9       3.7       35.7      -           -
# 2003      25.1          71.0      28.4       73.8   43.7           -
# 2056      31.1          65.4      32.8       62.1   61.6           -
# 1908      36.9          76.8      50.7       79.8   68.3        57.7
# 2105      21.6          72.2      18.9       67.2   31.3           -
#
#      num_students  student_staff_ratio international_students  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 818 entries, 2405 to 2134
# Data columns (total 15 columns):
# world_rank                818 non-null object
# university_name           818 non-null object
# country                   818 non-null object
# teaching                  818 non-null float64
# international             818 non-null object
# research                  818 non-null float64
# citations                 818 non-null float64
# income                    818 non-null object
# total_score               818 non-null object
# num_students              796 non-null object
# student_staff_ratio       796 non-null float64
# international_students    793 non-null object
# female_male_ratio         742 non-null object
# year                      818 non-null int64
# check                     818 non-null int64
# dtypes: float64(4), int64(2), object(9)
# memory usage: 102.2+ KB

# %%
plt.figure()
plt.hist(df_max["object"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-4b635d1b9677> in <module>
#       1 plt.figure()
# ...
